# %% [markdown]
# <a href="https://colab.research.google.com/github/yashasree2007/2025-2026-even--AI-B--DS-venkata-yashasree_4071/blob/main/week2_10.2.2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#filtering data
import pandas as pd
data={
    "ID":[101,102,103,104,105],
    "Name":["Alice","Bob","Charlie","david","eva"]
}
df=pd.DataFrame(data)
print("original DataFrame")
print(df)
print(df[df["Name"]=='Alice'])
print(df[df["Name"]=='Charlie'])
# Out:
# original DataFrame
#     ID     Name
# 0  101    Alice
# 1  102      Bob
# 2  103  Charlie
# 3  104    david
# 4  105      eva
#     ID   Name
# 0  101  Alice
#     ID     Name
# 2  103  Charlie

# %%
#Data manipulation
import pandas as pd
data={
    "Name":['A','B','C'],
    "Age":[20,21,22],
    "Marks":[70,80,90]
}
df=pd.DataFrame(data)
print("original data")
print(df)
df["Bonus"]=5
print("\n after adding Bonus:")
print(df)
df["Marks"]=df["Marks"]+2
print("\n after increasing Marks:")
print(df)
df["Total"]=df["Marks"]+df["Bonus"]
print("\n after adding total:")
print(df)
df.loc[0,"Age"]=21
print("\n After changing age of first std")
print(df)
df.rename(columns={"total":"final"},inplace=True)
print(df)
df.drop("Bonus",axis=1,inplace=True)
print(df)
# Out:
# original data
#   Name  Age  Marks
# 0    A   20     70
# 1    B   21     80
# 2    C   22     90
#
#  after adding Bonus:
#   Name  Age  Marks  Bonus
# 0    A   20     70      5
# 1    B   21     80      5
# 2    C   22     90      5
#
#  after increasing Marks:
#   Name  Age  Marks  Bonus
# 0    A   20     72      5
# 1    B   21     82      5
# 2    C   22     92      5
#
#  after adding total:
#   Name  Age  Marks  Bonus  Total
# 0    A   20     72      5     77
# 1    B   21     82      5     87
# 2    C   22     92      5     97
#
#  After changing age of first std
#   Name  Age  Marks  Bonus  Total
# 0    A   21     72      5     77
# 1    B   21     82      5     87
# 2    C   22     92      5     97
#   Name  Age  Marks  Bonus  Total
# 0    A   21     72      5     77
# 1    B   21     82      5     87
# 2    C   22     92      5     97
#   Name  Age  Marks  Total
# 0    A   21     72     77
# 1    B   21     82     87
# 2    C   22     92     97

# %%
# Selection Sort
n = int(input("Enter no of elements: "))
arr = []
for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))
print("\nOriginal array:", arr)
for i in range(n - 1):
    min_index = i
    for j in range(i + 1, n):
        if arr[j] < arr[min_index]:
            min_index = j
    arr[i], arr[min_index] = arr[min_index], arr[i]
print("Sorted array:", arr)
# Out:
# Enter no of elements: 4
# Enter element 1: 5
# Enter element 2: 4
# Enter element 3: 2
# Enter element 4: 1
#
# Original array: [5, 4, 2, 1]
# Sorted array: [1, 2, 4, 5]

# %%
# Bubble Sort
n = int(input("Enter no of elements: "))
arr = []
for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))
for i in range(n - 1):
    for j in range(n - 1 - i):
        if arr[j] > arr[j + 1]:
            arr[j], arr[j + 1] = arr[j + 1], arr[j]
print("Sorted array:", arr)
# Out:
# Enter no of elements: 5
# Enter element 1: 8
# Enter element 2: 9
# Enter element 3: 6
# Enter element 4: 7
# Enter element 5: 5
# Sorted array: [5, 6, 7, 8, 9]

# %%
#Linear Search
n = int(input("enter no. of elements:"))
arr = []
for i in range(n):
    arr.append(int(input(f"enter element {i}:")))
key = int(input("enter element to search:"))
found = False
for i in range(n):
    if arr[i] == key:
        print(f"element {key} found at position {i+1}")
        foond = True
        break
if not found:
    print("element not found:")
# Out:
# enter no. of elements:5
# enter element 0:14
# enter element 1:15
# enter element 2:85
# enter element 3:65
# enter element 4:54
# enter element to search:14
# element 14 found at position 1
# element not found:

# %%
# Binary Search
n = int(input("Enter no. of elements: "))
arr = []
for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))
arr.sort()
print("Sorted array:", arr)
key = int(input("Enter element to search: "))
low = 0
high = n - 1
found = False
while low <= high:
    mid = (low + high) // 2
    if arr[mid] == key:
        print(f"Element {key} found at position {mid + 1}")
        found = True
        break
    elif key < arr[mid]:
        high = mid - 1
    else:
        low = mid + 1
if not found:
    print("Element not found")
# Out:
# Enter no. of elements: 5
# Enter element 1: 45
# Enter element 2: 58
# Enter element 3: 85
# Enter element 4: 95
# Enter element 5: 56
# Sorted array: [45, 56, 58, 85, 95]
# Enter element to search: 58
# Element 58 found at position 3

# %%
# Grouping
import pandas as pd
# Simple Dataframe
data = {
    "Department": ["IT", "IT", "HR", "HR", "Finance"],
    "Name": ["A", "B", "C", "D", "E"],
    "Marks": [80, 85, 75, 90, 88]
}
df = pd.DataFrame(data)
print("Original Data:")
print(df)
print("\n Average Marks by department:")
print(df.groupby("Department")["Marks"].mean())
print("\nTotal marks by department:")
print(df.groupby("Department")["Marks"].sum())
# Out:
# Original Data:
#   Department Name  Marks
# 0         IT    A     80
# 1         IT    B     85
# 2         HR    C     75
# 3         HR    D     90
# 4    Finance    E     88
#
#  Average Marks by department:
# Department
# Finance    88.0
# HR         82.5
# IT         82.5
# Name: Marks, dtype: float64
#
# Total marks by department:
# Department
# Finance     88
# HR         165
# IT         165
# Name: Marks, dtype: int64

# %%
# Rearrange
import pandas as pd
data = {
    "Name": ["A", "B", "C"],
    "Age": [22, 21, 23],
    "Marks": [85, 90, 80]
}
df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
# Rearranging rows by Marks (ascending)
df_sorted = df.sort_values(by="Marks")
print("\nAfter rearranging rows by marks (ascending):")
print(df_sorted)
# Rearranging rows by Marks (descending)
df_sorted_desc = df.sort_values(by="Marks", ascending=False)
print("\nAfter rearranging rows by marks (descending):")
print(df_sorted_desc)
# Rearranging columns
df_rearranged_cols = df[["Marks", "Name", "Age"]]
print("\nAfter rearranging columns:")
print(df_rearranged_cols)
# Out:
# Original DataFrame:
#   Name  Age  Marks
# 0    A   22     85
# 1    B   21     90
# 2    C   23     80
#
# After rearranging rows by marks (ascending):
#   Name  Age  Marks
# 2    C   23     80
# 0    A   22     85
# 1    B   21     90
#
# After rearranging rows by marks (descending):
#   Name  Age  Marks
# 1    B   21     90
# 0    A   22     85
# 2    C   23     80
#
# After rearranging columns:
#    Marks Name  Age
# 0     85    A   22
# 1     90    B   21
# 2     80    C   23

# %%
# Plotting
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.plot(x, y)
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("X-Y Graph")
plt.show()

# %%
# Ranking
import pandas as pd
data = {
    "Name": ["A", "B", "C", "D"],
    "Marks": [85, 92, 78, 80]
}
df = pd.DataFrame(data)
print("Original Data:")
print(df)
df["Rank"] = df["Marks"].rank(ascending=False)
print("\nAfter ranking:")
print(df)
# Out:
# Original Data:
#   Name  Marks
# 0    A     85
# 1    B     92
# 2    C     78
# 3    D     80
#
# After ranking:
#   Name  Marks  Rank
# 0    A     85   2.0
# 1    B     92   1.0
# 2    C     78   4.0
# 3    D     80   3.0

# %%
#BAR GRAPH
import matplotlib.pyplot as plt
subjects=['Maths','Physics','Chemistry','CS']
marks=[90,80,70,60]
plt.bar(subjects,marks)
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.title("Marks in subjects")
plt.show()

# %%
#SCATTERED GRAPH
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[5,7,8,6,9]
plt.scatter(x,y)
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Scatter graph")
plt.show()

# %%
#HISTOGRAM
import matplotlib.pyplot as plt
marks=[90,80,70,60,50,40,30,20,10]
plt.hist(marks)
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
#PIE CHART
import matplotlib.pyplot as plt
activities=['study','sleep','play','others']
hours=[6,4,8,6]
plt.pie(hours,labels=activities,autopct="%1.1f%%")
plt.title("Daily activities")
plt.show()
